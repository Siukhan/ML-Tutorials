# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Import data
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("Area (sqr ft)")
plt.ylabel("Price (US$)")
plt.scatter(df.area, df.price, color = 'red', marker = '+');

# %%
# Create linear regression model
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
# Predict price for a house with area 3300 sqr ft
reg.predict([[3300]])
# Out:
# c:\Users\shirf\miniconda3\envs\python_ml\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_  # m
# Out:
# array([135.78767123])

# %%
reg.intercept_  # b
# Out:
# 180616.43835616432

# %%
# y = mx + b
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
135.78767123*5000 + 180616.43835616432
# Out:
# 859554.7945061643

# %%
d = pd.read_csv("areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1200
# 2  1500

# %%
p = reg.predict(d)
d['prices'] = p
d
# Out:
#     area         prices
# 0   1000  316404.109589
# 1   1200  343561.643836
# 2   1500  384297.945205
# 3   1700  411455.479452
# 4   1900  438613.013699
# 5   2100  465770.547945
# 6   2350  499717.465753
# 7   2500  520085.616438
# 8   2700  547243.150685
# 9   3100  601558.219178
# 10  3400  642294.520548
# 11  3700  683030.821918
# 12  3900  710188.356164
# 13  4100  737345.890411
# 14  4300  764503.424658
# 15  4500  791660.958904
# 16  4650  812029.109589
# 17  4800  832397.260274
# 18  5100  873133.561644
# 19  5500  927448.630137

# %%
d.to_csv("predictions.csv", index = False)

# %%
plt.xlabel("Area (sqr ft)")
plt.ylabel("Price (US$)")
plt.scatter(df.area, df.price, color = 'red', marker = '+');
plt.plot(df.area, reg.predict(df[['area']]), color = 'blue');
